# %%
# %matplotlib notebook

# %%
import nibabel as nb
import numpy as np
import matplotlib.pyplot as plt
from glob import glob

# %%
# exp = 'JH_inject_02'
# gre = '31'
# se = '32'

exp = 'JH_inject_04'
gre = '14'
se = '15'

# exp = 'JH_inject_05'
# gre = '11'
# se = '12'
# rare='10'

# %%
data_gre = nb.load(glob(('/home/julia/projects/fmri_training/*%s*_nifti/*/*_%s/*_%s.nii.gz')%(exp,gre,gre))[0]
).get_data()
data_se = nb.load(glob(('/home/julia/projects/fmri_training/*%s*_nifti/*/*_%s/*_%s.nii.gz')%(exp,se,se))[0]
).get_data()
# data_rare = nb.load(glob(('/home/julia/projects/fmri_training/*%s*_nifti/*/*_%s/*_%s.nii.gz')%(exp,rare,rare))[0]
# ).get_data()

# %%
data_rare.shape
# Out:
# (200, 160, 20)

# %%
fig_full = plt.figure(figsize=(10,30))
plt.suptitle('RARE')
for slice_n in range(data_rare.shape[2]):
    fig_full.add_subplot(10,2,slice_n+1)
    plt.axis('off')
    plt.imshow(data_rare[:,:,slice_n].T, cmap="Greys_r")
plt.tight_layout()

# %%
fig_full = plt.figure(figsize=(10,20))
plt.suptitle('GRE EPI')
for slice_n in range(data_gre.shape[2]):
    fig_full.add_subplot(7,2,slice_n+1)
    plt.axis('off')
    plt.imshow(data_gre[:,:,slice_n].T, cmap="Greys_r")
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
fig_full = plt.figure(figsize=(10,20))
plt.suptitle('SE EPI')
for slice_n in range(data_se.shape[2]):
    fig_full.add_subplot(8,2,slice_n+1)
    plt.axis('off')
    plt.imshow(data_se[:,:,slice_n].T, cmap="Greys_r")
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="1250">
